# %%
import streamlit as st
import pickle
import requests

# ----------------------------
# Secure API Key
# ----------------------------
api_key = st.secrets["OMDB_API_KEY"]

# ----------------------------
# Load Data
# ----------------------------
movies = pickle.load(open('movies.pkl', 'rb'))
similarity = pickle.load(open('similarity.pkl', 'rb'))

# ----------------------------
# Fetch Movie Details
# ----------------------------
def fetch_movie_details(title):
    url = f"http://www.omdbapi.com/?t={title}&apikey={api_key}"
    response = requests.get(url)
    data = response.json()

    poster = data.get("Poster")
    plot = data.get("Plot")

    if poster == "N/A" or poster is None:
        poster = None

    if plot == "N/A" or plot is None:
        plot = "No description available."

    return poster, plot


# ----------------------------
# Recommendation Function
# ----------------------------
def recommend(movie):
    movie_index = movies[movies['title'] == movie].index[0]
    distances = similarity[movie_index]

    movies_list = sorted(
        list(enumerate(distances)),
        reverse=True,
        key=lambda x: x[1]
    )[1:6]

    names = []
    posters = []
    plots = []

    for i in movies_list:
        title = movies.iloc[i[0]].title
        poster, plot = fetch_movie_details(title)

        names.append(title)
        posters.append(poster)
        plots.append(plot)

    return names, posters, plots


# ----------------------------
# UI
# ----------------------------
st.title("🎬 Movie Recommender System")

selected_movie = st.selectbox(
    "Choose a movie",
    movies['title'].values
)

if st.button("Recommend"):

    st.subheader("🎥 Selected Movie")

    selected_poster, selected_plot = fetch_movie_details(selected_movie)

    col1, col2 = st.columns([1, 2])

    with col1:
        if selected_poster:
            st.image(selected_poster, use_container_width=True)
        else:
            st.write("No Poster Available")

    with col2:
        st.markdown(f"### {selected_movie}")
        st.write(selected_plot)

    st.subheader("🍿 Recommended Movies")

    names, posters, plots = recommend(selected_movie)

    cols = st.columns(5)

    for col, name, poster, plot in zip(cols, names, posters, plots):
        with col:
            if poster:
                st.image(poster, use_container_width=True)
            else:
                st.write("No Poster Available")

            st.markdown(f"**{name}**")
            st.caption(plot[:120] + "...")
# Out:
# 2026-02-23 13:36:19.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 13:36:19.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 13:36:19.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 13:36:19.323 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 13:36:19.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 13:36:19.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 13:36:19.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 13:36:19.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 13:36:19.335 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 13:36:19.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 13:36:19.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 13:36:19.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 13:36:19.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 13:36:19.340 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 13:36:19.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 13:36:19.343 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /home/student/anaconda3/lib/python3.13/site-packages (1.51.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /home/student/anaconda3/lib/python3.13/site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /home/student/anaconda3/lib/python3.13/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /home/student/anaconda3/lib/python3.13/site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in /home/student/anaconda3/lib/python3.13/site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in /home/student/anaconda3/lib/python3.13/site-packages (from streamlit) (2.3.5)
# Requirement already satisfied: packaging<26,>=20 in /home/student/anaconda3/lib/python3.13/site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /home/student/anaconda3/lib/python3.13/site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in /home/student/anaconda3/lib/python3.13/site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /home/student/anaconda3/lib/python3.13/site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow<22,>=7.0 in /home/student/anaconda3/lib/python3.13/site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/student/anaconda3/lib/python3.13/site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /home/student/anaconda3/lib/python3.13/site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/student/anaconda3/lib/python3.13/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /home/student/anaconda3/lib/python3.13/site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /home/student/anaconda3/lib/python3.13/site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/student/anaconda3/lib/python3.13/site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /home/student/anaconda3/lib/python3.13/site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in /home/student/anaconda3/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /home/student/anaconda3/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in /home/student/anaconda3/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.7.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/student/anaconda3/lib/python3.13/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/student/anaconda3/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/student/anaconda3/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/student/anaconda3/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/student/anaconda3/lib/python3.13/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/student/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/student/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/student/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/student/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (2025.11.12)
# Requirement already satisfied: attrs>=22.2.0 in /home/student/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/student/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/student/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/student/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.28.0)
# Requirement already satisfied: six>=1.5 in /home/student/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/student/anaconda3/lib/python3.13/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)

# %%
import os
os.listdir()
# Out:
# ['tmdb_5000_credits.csv',
#  'app.py',
#  'similarity.pkl',
#  'tmdb_5000_movies.csv',
#  'dummy.png',
#  'dummy1.jpg',
#  'movies.pkl',
#  'movie recommender system.ipynb',
#  '.ipynb_checkpoints',
#  'dummy.jpg',
#  'streamlit.ipynb']

# %%
import os
os.listdir()
# Out:
# ['tmdb_5000_credits.csv',
#  'app.py',
#  'similarity.pkl',
#  'tmdb_5000_movies.csv',
#  'dummy.png',
#  'dummy1.jpg',
#  'movies.pkl',
#  'movie recommender system.ipynb',
#  '.ipynb_checkpoints',
#  'dummy.jpg',
#  'streamlit.ipynb']

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /home/student/anaconda3/lib/python3.13/site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/student/anaconda3/lib/python3.13/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/student/anaconda3/lib/python3.13/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/student/anaconda3/lib/python3.13/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/student/anaconda3/lib/python3.13/site-packages (from requests) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.
